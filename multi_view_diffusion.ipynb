# %% [markdown]
# # Multi-view Diffusion

# %% [markdown]
# Multi-view diffusion is a type of diffusion model that turns an image of an object into multiple views of that object.

# %% [markdown]
# ## Setup

# %% [markdown]
# Install the required libraries.
#
# Here, we use a custom [requirements file](https://huggingface.co/spaces/dylanebert/multi-view-diffusion/blob/main/requirements.txt) to install a large number of dependencies. This is because the [Diffusers](https://huggingface.co/docs/diffusers/en/index) library doesn't officially support multi-view diffusion.

# %%
# !pip install -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt
# Out:
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 1)) (0.32.1)
# Requirement already satisfied: aiofiles==23.2.1 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 2)) (23.2.1)
# Requirement already satisfied: altair==5.2.0 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 3)) (5.2.0)
# Requirement already satisfied: annotated-types==0.6.0 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 4)) (0.6.0)
# Requirement already satisfied: anyio==4.3.0 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 5)) (4.3.0)
# Requirement already satisfied: attrs==23.2.0 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 6)) (23.2.0)
# Requirement already satisfied: certifi==2024.2.2 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 7)) (2024.2.2)
# Requirement already satisfied: charset-normalizer==3.3.2 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 8)) (3.3.2)
# Requirement already satisfied: click==8.1.7 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 9)) (8.1.7)
# Requirement already satisfied: colorama==0.4.6 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 10)) (0.4.6)
# Requirement already satisfied: contourpy==1.2.0 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 11)) (1.2.0)
# Requirement already satisfied: cycler==0.12.1 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 12)) (0.12.1)
# Requirement already satisfied: diffusers==0.27.2 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 13)) (0.27.2)
# Requirement already satisfied: einops==0.7.0 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 14)) (0.7.0)
# Requirement already satisfied: exceptiongroup==1.2.0 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 15)) (1.2.0)
# Requirement already satisfied: executing==2.0.1 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 16)) (2.0.1)
# Requirement already satisfied: fastapi==0.110.0 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 17)) (0.110.0)
# Requirement already satisfied: ffmpy==0.3.2 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 18)) (0.3.2)
# Requirement already satisfied: filelock==3.13.3 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 19)) (3.13.3)
# Requirement already satisfied: fonttools==4.50.0 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 20)) (4.50.0)
# Requirement already satisfied: fsspec==2024.3.1 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 21)) (2024.3.1)
# Requirement already satisfied: gradio==4.24.0 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 22)) (4.24.0)
# Requirement already satisfied: gradio_client==0.14.0 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 23)) (0.14.0)
# Requirement already satisfied: h11==0.14.0 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 24)) (0.14.0)
# Requirement already satisfied: httpcore==1.0.5 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 25)) (1.0.5)
# Requirement already satisfied: httpx==0.27.0 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 26)) (0.27.0)
# Requirement already satisfied: huggingface-hub==0.22.2 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 27)) (0.22.2)
# Requirement already satisfied: idna==3.6 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 28)) (3.6)
# Requirement already satisfied: importlib_metadata==7.1.0 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 29)) (7.1.0)
# Requirement already satisfied: importlib_resources==6.4.0 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 30)) (6.4.0)
# Requirement already satisfied: Jinja2==3.1.3 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 31)) (3.1.3)
# Requirement already satisfied: jsonschema==4.21.1 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 32)) (4.21.1)
# Requirement already satisfied: jsonschema-specifications==2023.12.1 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 33)) (2023.12.1)
# Requirement already satisfied: kiui==0.2.7 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 34)) (0.2.7)
# Requirement already satisfied: kiwisolver==1.4.5 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 35)) (1.4.5)
# Requirement already satisfied: lazy_loader==0.3 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 36)) (0.3)
# Requirement already satisfied: markdown-it-py==3.0.0 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 37)) (3.0.0)
# Requirement already satisfied: MarkupSafe==2.1.5 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 38)) (2.1.5)
# Requirement already satisfied: matplotlib==3.8.3 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 39)) (3.8.3)
# Requirement already satisfied: mdurl==0.1.2 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 40)) (0.1.2)
# Requirement already satisfied: mpmath==1.3.0 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 41)) (1.3.0)
# Requirement already satisfied: networkx==3.2.1 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 42)) (3.2.1)
# Requirement already satisfied: numpy==1.26.4 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 43)) (1.26.4)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 44)) (12.1.3.1)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 45)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 46)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 47)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 48)) (8.9.2.26)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 49)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 50)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 51)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 52)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 53)) (2.19.3)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.99 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 54)) (12.4.99)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 55)) (12.1.105)
# Requirement already satisfied: objprint==0.2.3 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 56)) (0.2.3)
# Requirement already satisfied: opencv-python==4.9.0.80 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 57)) (4.9.0.80)
# Requirement already satisfied: orjson==3.10.0 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 58)) (3.10.0)
# Requirement already satisfied: packaging==24.0 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 59)) (24.0)
# Requirement already satisfied: pandas==2.2.1 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 60)) (2.2.1)
# Requirement already satisfied: pillow==10.2.0 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 61)) (10.2.0)
# Requirement already satisfied: psutil==5.9.8 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 62)) (5.9.8)
# Requirement already satisfied: pydantic==2.6.4 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 63)) (2.6.4)
# Requirement already satisfied: pydantic_core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 64)) (2.16.3)
# Requirement already satisfied: pydub==0.25.1 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 65)) (0.25.1)
# Requirement already satisfied: Pygments==2.17.2 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 66)) (2.17.2)
# Requirement already satisfied: pyparsing==3.1.2 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 67)) (3.1.2)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 68)) (2.9.0.post0)
# Requirement already satisfied: python-multipart==0.0.9 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 69)) (0.0.9)
# Requirement already satisfied: pytz==2024.1 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 70)) (2024.1)
# Requirement already satisfied: PyYAML==6.0.1 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 71)) (6.0.1)
# Requirement already satisfied: referencing==0.34.0 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 72)) (0.34.0)
# Requirement already satisfied: regex==2023.12.25 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 73)) (2023.12.25)
# Requirement already satisfied: requests==2.31.0 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 74)) (2.31.0)
# Requirement already satisfied: rich==13.7.1 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 75)) (13.7.1)
# Requirement already satisfied: rpds-py==0.18.0 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 76)) (0.18.0)
# Requirement already satisfied: ruff==0.3.4 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 77)) (0.3.4)
# Requirement already satisfied: safetensors==0.4.2 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 78)) (0.4.2)
# Requirement already satisfied: scipy==1.12.0 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 79)) (1.12.0)
# Requirement already satisfied: semantic-version==2.10.0 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 80)) (2.10.0)
# Requirement already satisfied: shellingham==1.5.4 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 81)) (1.5.4)
# Requirement already satisfied: six==1.16.0 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 82)) (1.16.0)
# Requirement already satisfied: sniffio==1.3.1 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 83)) (1.3.1)
# Requirement already satisfied: spaces==0.25.0 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 84)) (0.25.0)
# Requirement already satisfied: starlette==0.36.3 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 85)) (0.36.3)
# Requirement already satisfied: sympy==1.12 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 86)) (1.12)
# Requirement already satisfied: tokenizers==0.15.2 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 87)) (0.15.2)
# Requirement already satisfied: tomlkit==0.12.0 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 88)) (0.12.0)
# Requirement already satisfied: toolz==0.12.1 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 89)) (0.12.1)
# Requirement already satisfied: torch==2.2.0 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 90)) (2.2.0)
# Requirement already satisfied: tqdm==4.66.2 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 91)) (4.66.2)
# Requirement already satisfied: transformers==4.39.2 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 92)) (4.39.2)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 93)) (2.2.0)
# Requirement already satisfied: typer==0.11.1 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 94)) (0.11.1)
# Requirement already satisfied: typing_extensions==4.10.0 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 95)) (4.10.0)
# Requirement already satisfied: tzdata==2024.1 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 96)) (2024.1)
# Requirement already satisfied: urllib3==2.2.1 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 97)) (2.2.1)
# Requirement already satisfied: uvicorn==0.29.0 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 98)) (0.29.0)
# Requirement already satisfied: varname==0.13.0 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 99)) (0.13.0)
# Requirement already satisfied: websockets==11.0.3 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 100)) (11.0.3)
# Requirement already satisfied: xformers in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 101)) (0.0.24)
# Requirement already satisfied: zipp==3.18.1 in /usr/local/lib/python3.10/dist-packages (from -r https://huggingface.co/spaces/dylanebert/multi-view-diffusion/raw/main/requirements.txt (line 102)) (3.18.1)

# %% [markdown]
# ## Pipeline

# %% [markdown]
# Create a multi-view diffusion pipeline. Diffusers doesn't officially support multi-view-diffusion, so we load a [custom pipeline](https://huggingface.co/docs/diffusers/v0.6.0/en/using-diffusers/custom_pipelines).

# %%
import torch
from diffusers import DiffusionPipeline

multi_view_diffusion_pipeline = DiffusionPipeline.from_pretrained(
    "dylanebert/multi-view-diffusion",
    custom_pipeline="dylanebert/multi-view-diffusion",
    torch_dtype=torch.float16,
    trust_remote_code=True,
).to("cuda")
# Out:
# Keyword arguments {'trust_remote_code': True} are not expected by MVDreamPipeline and will be ignored.
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]

# %% [markdown]
# Load the input image.

# %%
import requests
from PIL import Image
from io import BytesIO


image_url = "https://huggingface.co/datasets/dylanebert/3d-arena/resolve/main/inputs/images/a_cat_statue.jpg"
response = requests.get(image_url)
image = Image.open(BytesIO(response.content))
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>

# %% [markdown]
# Pass the image through the multi-view diffusion pipeline.

# %%
import numpy as np

def create_image_grid(images):
    images = [Image.fromarray((img * 255).astype("uint8")) for img in images]

    width, height = images[0].size
    grid_img = Image.new("RGB", (2 * width, 2 * height))

    grid_img.paste(images[0], (0, 0))
    grid_img.paste(images[1], (width, 0))
    grid_img.paste(images[2], (0, height))
    grid_img.paste(images[3], (width, height))

    return grid_img

image = np.array(image, dtype=np.float32) / 255.0
images = multi_view_diffusion_pipeline("", image, guidance_scale=5, num_inference_steps=30, elevation=0)

create_image_grid(images)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %% [markdown]
# ## Gradio Demo

# %%
import gradio as gr

def run(image):
  image = np.array(image, dtype=np.float32) / 255.0
  images = multi_view_diffusion_pipeline("", image, guidance_scale=5, num_inference_steps=30, elevation=0)

  images = [Image.fromarray((img * 255).astype("uint8")) for img in images]

  width, height = images[0].size
  grid_img = Image.new("RGB", (2 * width, 2 * height))

  grid_img.paste(images[0], (0, 0))
  grid_img.paste(images[1], (width, 0))
  grid_img.paste(images[2], (0, height))
  grid_img.paste(images[3], (width, height))

  return grid_img

demo = gr.Interface(fn=run, inputs="image", outputs="image")
demo.launch()
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# IMPORTANT: You are using gradio version 4.24.0, however version 4.29.0 is available, please upgrade.
# --------
# Running on public URL: https://ff965f85d12704adfc.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://ff965f85d12704adfc.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
